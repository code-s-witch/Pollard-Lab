# %%
wdir= '../../../data/projects/morin/'
inFile = open(wdir+'proseq_overlapping_enhancers_filtered.bed', 'r')
l2f_change = {}
for line in inFile:
    splitLine = line.strip().split('\t')
#     print(splitLine)
    chrom = splitLine[0]
    start =  splitLine[1]
    end = splitLine[2]
    key = chrom + ':' +  start + ':'+ end
    val = float(splitLine[3])
    if l2f_change.get(key)!=None:
        #check if key exists, if it does append to it
        newList = l2f_change[key]
        newList.append(val)
        l2f_change[key] = newList
    else:
        #if key does not exist then create one
        new_List = []
        new_List.append(val)
        l2f_change[key] = new_List
        
inFile.close()
# print(l2f_change.items())
#for enhancer and list of l2f change values, avg the values
for e,l in l2f_change.items():
#     print(len(l))
    sum_ = 0
    for x in range(0,len(l)):
        sum_ += l[x]     
    avg = sum_/len(l)
    l2f_change[e] = avg
    
# print(l2f_change.items())

#insert the zeros for regions without overlap
inFile = open(wdir+'proseq_intergenic_counts.csv', 'r')
enhancers_key = {}
for line in inFile:
    splitLine = line.strip().split('\t')
#     print(splitLine)
    chrom = splitLine[0]
    start =  splitLine[1]
    end = splitLine[2]
    key = chrom + ':' + start + ':'+ end
    count = float(splitLine[3])
    if count == 0:
        l2f_change[key] = 0      
inFile.close()

# print(len(l2f_change.keys()))
#since the dictionary is unordered we have to order it so we can create a 1:1 correspondence with enhancer.bed
outFile = open(wdir+'enhancers_log2foldchange.csv', 'a+')
for key, l2f in l2f_change.items():
    splitLine = key.split(':')
    chrom = splitLine[0]
    start = splitLine[1]
    end = splitLine[2]
#     print(key.split(':'))
    line = chrom +'\t'+ start + '\t' + end + '\t' + str(l2f)+ '\n'
    print(line)
#     outFile.write(line)
outFile.close()
# print(len(l2f_change.keys()))
#key = start:end
#values = [log2fold1, ......log2fold9]
#avg values then set the new avg value to the key

#read in enhancers.bed then check 
#
# Out:
# chr1	14772786	14801252	1.53683435518639
#
# chr1	31093926	31105103	0.986674258904025
#
# chr1	33672550	33697347	1.0251161402003857
#
# chr1	39731637	39770704	0.12234420512
#
# chr1	40171704	40182137	-0.167291495019385
#
# chr1	52421542	52428293	-0.881452824002655
#
# chr1	59422874	59459393	-0.5362376237536123
#
# chr1	60641311	60669562	-0.5391248885168838
#
# chr1	79999054	80053203	0.43786502664082005
#
# chr1	86470139	86473147	0.395255887135943
#
# chr1	90650718	90669592	0.6437903272311825
#
# chr1	90706397	90758784	-0.29193937273679693
#
# chr1	90894854	90910184	-1.4621104074128
#
# chr1	133177447	133241399	-0.6529722817319027
#
# chr1	133468847	133471936	0.43433089830274
#
# chr1	134098104	134100108	-0.382283872029355
#
# chr1	182982840	182991536	1.04659736015328
#
# chr1	186399566	186414392	1.16294986607977
#
# chr1	189615171	189634176	-0.05597850500335
#
# chr1	192778705	192841596	1.2842872143820385
#
# chr2	27771841	27874911	0.6096907825588392
#
# ...

# %%
sum_ = 0
l = [1.4, 2.4]
for x in range(0,len(l)):
        sum_ += l[x] 
print(sum_)
# Out:
# 3.8

# %%
# ('14772786:14801252', [1.53683435518639]), 
# ('31093926:31105103', [0.986674258904025]), 
('33672550:33697347', [0.811628746095861, 1.4896635579069, 0.774056116598396]),
('39731637:39770704', [0.614601583877509, 1.02548162556411, -1.2952062623196, 0.144499873357981]), 
# ('40171704:40182137', [-0.167291495019385]), 
# ('52421542:52428293', [-0.881452824002655]), 
('59422874:59459393', [-0.857699929162661, 0.447079519620184, -1.19809246171836]),
('60641311:60669562', [-0.493363117711774, -1.0799818786013, -2.30976680008331, 1.13065235304822, 0.056835000763745]), 
# ('79999054:80053203', [1.07073332906975, -0.19500327578811]), 
# ('86470139:86473147', [0.395255887135943]), 
# ('90650718:90669592', [1.20063539768579, 0.086945256776575]),

# %%
# '14772786:14801252', 1.53683435518639),
# ('31093926:31105103', 0.986674258904025), 
('33672550:33697347', 1.0251161402003857), 
('39731637:39770704', 0.12234420512), 
# ('40171704:40182137', -0.167291495019385), 
# ('52421542:52428293', -0.881452824002655), 
('59422874:59459393', -0.5362376237536123), 
('60641311:60669562', -0.5391248885168838), 
# ('79999054:80053203', 0.43786502664082005), 
# ('86470139:86473147', 0.395255887135943), 
# ('90650718:90669592', 0.6437903272311825),

# %%
print((-0.857699929162661+ 0.447079519620184+ -1.19809246171836)/3)
# Out:
# -0.5362376237536123

# %%
key = 'asd:fgfg:cccc'
print(key.split(':'))
# Out:
# ['asd', 'fgfg', 'cccc']

# %%
wdir= '../../../data/projects/morin/'


#create a dictionary that follows the order of enhancers.bed
inFile = open(wdir+'proseq_intergenic_counts.csv', 'r')
l2f_change = {}
for line in inFile:
    splitLine = line.strip().split('\t')
#     print(splitLine)
    chrom = splitLine[0]
    start =  splitLine[1]
    end = splitLine[2]
    key = chrom + ':' + start + ':'+ end
    start_list = []
    l2f_change[key] = start_list     
inFile.close()


inFile = open(wdir+'proseq_overlapping_enhancers_filtered.bed', 'r')
for line in inFile:
    splitLine = line.strip().split('\t')
#     print(splitLine)
    chrom = splitLine[0]
    start =  splitLine[1]
    end = splitLine[2]
    key = chrom + ':' +  start + ':'+ end
    val = float(splitLine[3])
    if l2f_change.get(key)!=None:
        #check if key exists, if it does append to it
        newList = l2f_change[key]
        newList.append(val)
        l2f_change[key] = newList
inFile.close()
#fill empty lists with 0        
for key, val in l2f_change.items():
    if not val:
        l2f_change[key] = [0]        


# print(l2f_change.items())

#for enhancer and list of l2f change values, avg the values
for e,l in l2f_change.items():
#     print(len(l))
    sum_ = 0
    for x in range(0,len(l)):
        sum_ += l[x]     
    avg = sum_/len(l)
    l2f_change[e] = avg
    
# print(l2f_change.items())


# print(len(l2f_change.keys()))
#since the dictionary is unordered we have to order it so we can create a 1:1 correspondence with enhancer.bed
outFile = open(wdir+'enhancers_log2foldchange.csv', 'a+')
for key, l2f in l2f_change.items():
    splitLine = key.split(':')
    chrom = splitLine[0]
    start = splitLine[1]
    end = splitLine[2]
#     print(key.split(':'))
    line = chrom +'\t'+ start + '\t' + end + '\t' + str(l2f)+ '\n'
#     print(line)
    outFile.write(line)
outFile.close()
# print(len(l2f_change.keys()))

# %%
('chr1:14772786:14801252', [1.53683435518639]), 
('chr1:31093926:31105103', [0.986674258904025]), 
('chr1:33672550:33697347', [0.811628746095861, 1.4896635579069, 0.774056116598396]), 
('chr1:39731637:39770704', [0.614601583877509, 1.02548162556411, -1.2952062623196, 0.144499873357981]), 
('chr1:40171704:40182137', [-0.167291495019385]), 
('chr1:45663829:45676350', [0]), 
('chr1:52421542:52428293', [-0.881452824002655]), 
('chr1:59422874:59459393', [-0.857699929162661, 0.447079519620184, -1.19809246171836]), 
('chr1:60641311:60669562', [-0.493363117711774, -1.0799818786013, -2.30976680008331, 1.13065235304822, 0.056835000763745]), 
('chr1:64753026:64758239', [0]), 
('chr1:78852273:78865100', [0]), 
('chr1:79999054:80053203', [1.07073332906975, -0.19500327578811]), 
('chr1:86433798:86448782', [0]), 
('chr1:86470139:86473147', [0.395255887135943]), 
('chr1:90495086:90525105', [0]), 
('chr1:90650718:90669592', [1.20063539768579, 0.086945256776575]),

# %%
[('chr1:14772786:14801252', 1.53683435518639),
 ('chr1:31093926:31105103', 0.986674258904025), 
 ('chr1:33672550:33697347', 1.0251161402003857), 
 ('chr1:39731637:39770704', 0.12234420512), 
 ('chr1:40171704:40182137', -0.167291495019385), 
 ('chr1:45663829:45676350', 0.0), 
 ('chr1:52421542:52428293', -0.881452824002655), 
 ('chr1:59422874:59459393', -0.5362376237536123), 
 ('chr1:60641311:60669562', -0.5391248885168838), 
 ('chr1:64753026:64758239', 0.0), 
 ('chr1:78852273:78865100', 0.0), 
 ('chr1:79999054:80053203', 0.43786502664082005), 
 ('chr1:86433798:86448782', 0.0), 
 ('chr1:86470139:86473147', 0.395255887135943), 
 ('chr1:90495086:90525105', 0.0), 
 ('chr1:90650718:90669592', 0.6437903272311825)
